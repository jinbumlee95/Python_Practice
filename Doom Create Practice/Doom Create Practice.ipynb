# %%
import pygame
import gameObject
import doomFunctions
pygame.init()
size = [1024 , 720]
title = 'pyGame Example'
screen = pygame.display.set_mode(size)
pygame.display.set_caption(title)
clock = pygame.time.Clock()

doomFunctions.init(screen)

running = True
while running : 
    #   4-1. FPS(Frames per Sec) 설정
    clock.tick(60)
    #   4-2. 입력(키보드, 마우스)의 감지
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

    doomFunctions.render_objects()
    doomFunctions.move_hero() 
    
    
    # 일단 시야 따라서 움직이는거 구현했고 # 구현 완료
    # 내적 계산 이후 , 거리 기준으로 doom_guy.v_distance 이내인 적들에 대해서
    # self.vison = 60 cos 랑  내적값이랑 비교해서 있으면 표기하는데 # 처리완료
    # 적과 내 x 축 상의 거리가 화면 안쪽이면 표기? # 처리완료
    # 화면 로테이팅은 어떻게? # 처리완료


    
    # 그건 표기는 표기고, 화면상에서 위치는 어떻게? > 이제 이거 처리 해야함
    # 1. 벽 > 어떻게 해야 벽으로 막힌것 처럼 만들 수 있지?
    # 2. 적 > 벽뒤에 있는 적은 또 따로 랜더링 안해도 될거 같은데..?
    # 3. 벽에 가로 막히는건 어떻게?"????????????"
    # 4. 여러 오브젝트를 랜더링 한다면, 거리 순서대로 렌더 한 후에 나를 랜더 한다? 
    # 5. 몹이 나를 볼 수 있다 = 몹을 렌더링 한다. > 몹이 나한테 다가온다 
    
pygame.quit()
